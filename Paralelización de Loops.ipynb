# %%
import pandas as pd
import numpy as np
from joblib import Parallel, delayed

df = pd.read_csv(r"C:\Users\marcos.sandovalr\Documents\Marcos Privada\Python Big Data\Python-TensorFlow-for-Machine-Learning-Neural-Network-Text-Classification-Tutorial\base_datos_2008.csv", nrows=100000)
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           NaN          NaN      NaN
# 2               NaN         0           NaN          NaN      NaN
# 3               NaN         0           NaN          NaN      NaN
# 4               NaN         0           2.0          0.0      0.0
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            0.0               32.0
#
# [5 rows x 29 columns]

# %%
df_sub = df[['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']]
df_sub.head()
# Out:
#    CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 0           NaN           NaN       NaN            NaN                NaN
# 1           NaN           NaN       NaN            NaN                NaN
# 2           NaN           NaN       NaN            NaN                NaN
# 3           NaN           NaN       NaN            NaN                NaN
# 4           2.0           0.0       0.0            0.0               32.0

# %%
def retraso_maximo(fila):
    if not np.isnan(fila).any():
        names = ['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']
        return names[fila.index(max(fila))]
    else:
        return "None"

# %%
results = []
for fila in df_sub.values.tolist():
    results.append(retraso_maximo(fila))

# %%
results
# Out:
# ['None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'SecurityDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'NASDelay',
#  'NASDelay',
#  'CarrierDelay',
#  'NASDelay',
#  'None',
#  'NASDelay',
#  'NASDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'NASDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'NASDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'SecurityDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'NASDelay',
#  'SecurityDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'SecurityDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'NASDelay',
#  'LateAircraftDelay',
#  'NASDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'NASDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'WeatherDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'NASDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'NASDelay',
#  'None',
#  'None',
#  'WeatherDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'NASDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'NASDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'NASDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'WeatherDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'None',
#  'CarrierDelay',
#  'NASDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'CarrierDelay',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'LateAircraftDelay',
#  'None',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'LateAircraftDelay',
#  'None',
#  'CarrierDelay',
#  'LateAircraftDelay',
#  'CarrierDelay',
#  'None',
#  'None',
#  'None',
#  ...]

# %%
result = Parallel(n_jobs =2, backend="multiprocessing")(
map(delayed(retraso_maximo), df_sub.values.tolist()))

# %%
result
