# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\marcos.sandovalr\Documents\Marcos Privada\Python Big Data\Python-TensorFlow-for-Machine-Learning-Neural-Network-Text-Classification-Tutorial\base_datos_2008.csv", nrows=1000000)

# %%
df.dropna(inplace=True, subset =["ArrDelay","DepDelay","Distance"])

# %%
sns.distplot(df["Distance"])
# Out:
# C:\Users\marcos.sandovalr\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Distance', ylabel='Density'>

# %%
sns.distplot(df["Distance"], kde = False)
# Out:
# C:\Users\marcos.sandovalr\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Distance'>

# %%
sns.distplot(df["Distance"], kde = False, bins = 100)
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
sns.kdeplot(df["ArrDelay"])
sns.kdeplot(df["DepDelay"])
plt.xlim([-300,300])
# Out:
# (-300.0, 300.0)

# %%
df2 = df[df["Origin"].isin(["ATL","HOU","IND"])].sample(frac=1).head(500)

# %%
sns.boxplot(x="DepDelay",y="Origin",data=df2)
plt.xlim([-20,150])
# Out:
# (-20.0, 150.0)
