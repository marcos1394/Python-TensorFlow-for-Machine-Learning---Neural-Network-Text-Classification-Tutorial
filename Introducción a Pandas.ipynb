# %%
#se esta importando el paquete pandas y despues se esta guardando la información de un archivo csv con el metodo read_csv en un data frame, el parametro nrows indica el número de filas que quieres tomar del data frame
import pandas as pd
df = pd.read_csv(r"C:\Users\marcos.sandovalr\Documents\Marcos Privada\Python Big Data\tvshows.csv", nrows = 1000)

# %%
#metodo para obtener las primeras cinco filas del dataframe, dentro de los parentesis del head puede colocar el número de filas que quieres visualizar en caso de que sea mayor a 5 que es el valor por defecto
df.head()
# Out:
#    rank                             title             release  \
# 0     1                 Rectify: Season 4    October 26, 2016
# 1     2  The Larry Sanders Show: Season 4       July 19, 1995
# 2     3              Murder One: Season 1  September 19, 1995
# 3     4  The Larry Sanders Show: Season 6      March 15, 1998
# 4     5            Breaking Bad: Season 5       July 15, 2012
#
#                                              summary  metascore userscore  \
# 0  Daniel tries to start a new life outside of Pa...         99       8.7
# 1  Comic Garry Shandling draws upon his own talk ...         99       5.8
# 2  One of several crime and law dramas created by...         99       6.4
# 3  Comic Garry Shandling draws upon his own talk ...         99       5.5
# 4  The final season for the award-winning drama b...         99       9.6
#
#                                                 link  \
# 0     https://www.metacritic.com/tv/rectify/season-4
# ...

# %%
#ejemplo del metodo head con mas filas a mostrar
df.head(10)
# Out:
#    rank                             title             release  \
# 0     1                 Rectify: Season 4    October 26, 2016
# 1     2  The Larry Sanders Show: Season 4       July 19, 1995
# 2     3              Murder One: Season 1  September 19, 1995
# 3     4  The Larry Sanders Show: Season 6      March 15, 1998
# 4     5            Breaking Bad: Season 5       July 15, 2012
# 5     6         The Office (UK): Season 3   December 26, 2003
# 6     7         The Office (UK): Season 1        July 9, 2001
# 7     8                Bo Burnham: Inside        May 30, 2021
# 8     9           The Leftovers: Season 3      April 16, 2017
# 9    10                The Wire: Season 3  September 19, 2004
#
#                                              summary  metascore userscore  \
# 0  Daniel tries to start a new life outside of Pa...         99       8.7
# 1  Comic Garry Shandling draws upon his own talk ...         99       5.8
# ...

# %%
#metodo para obtener las ultimas 5 filas del dataframe al igual que head puedes aumentar el número de filas a mostrar
df.tail()
# Out:
#      rank                            title            release  \
# 995   996  The Inbetweeners (UK): Season 1        May 1, 2008
# 996   997           Battle Creek: Season 1      March 1, 2015
# 997   998             London Spy: Season 1   January 21, 2016
# 998   999   The Bletchley Circle: Season 1  September 6, 2012
# 999  1000          The Middleman: Season 1      June 16, 2008
#
#                                                summary  metascore userscore  \
# 995  Will (Simon Bird) is the new kid who transfers...         73       6.1
# 996  Created (a dozen years ago) by Breaking Bad's ...         73       7.5
# 997  Danny (Ben Whishaw), a warehouse worker falls ...         73       7.7
# 998  Susan (Anna Maxwell Martin) contacts her frien...         73       8.5
# 999  In this adaptation of the Viper Comics graphic...         73       8.1
#
#                                                   link  \
# 995  https://www.metacritic.com/tv/the-inbetweeners...
# ...

# %%
#ejemplo utilizando tail con mas filas
df.tail(10)
# Out:
#      rank                            title            release  \
# 990   991       The Chair (2021): Season 1    August 20, 2021
# 991   992     The Beast Must Die: Season 1       July 5, 2021
# 992   993                Shangri-La (2019)      July 12, 2019
# 993   994               Cucumber: Season 1   January 22, 2015
# 994   995                 Thorne: Season 1   October 10, 2010
# 995   996  The Inbetweeners (UK): Season 1        May 1, 2008
# 996   997           Battle Creek: Season 1      March 1, 2015
# 997   998             London Spy: Season 1   January 21, 2016
# 998   999   The Bletchley Circle: Season 1  September 6, 2012
# 999  1000          The Middleman: Season 1      June 16, 2008
#
#                                                summary  metascore userscore  \
# 990  Dr. Ji-Yoon Kim (Sandra Oh) becomes the first ...         73       6.9
# 991  Frances Cairnes (Cush Jumbo) seeks out the per...         73       tbd
# ...

# %%
#reordenar nuestros datos con el metodo sample y el parametro frac es para especificar el porcentaje en valor decimal de las filas que queremos mostrar en este caso 1 significa que muestre el 100 %
df.sample(frac=1)
# Out:
#      rank                                              title  \
# 632   633                                     Lost: Season 5
# 284   285                                 Hannibal: Season 3
# 319   320                     The Kids in the Hall: Season 1
# 799   800                             Raising Hope: Season 1
# 152   153                                   Casual: Season 2
# ..    ...                                                ...
# 118   119                         Olive Kitteridge: Season 1
# 906   907                               Twin Peaks: Season 3
# 187   188                               Broad City: Season 3
# 552   553  Unbreakable Kimmy Schmidt: Kimmy Vs. The Reverend
# 640   641                Unbreakable Kimmy Schmidt: Season 1
#
#                 release                                            summary  \
# 632    January 21, 2009  The answers to when/where did the island go an...
# 284        June 4, 2015  The hunt for Hannibal is on as third season in...
# ...

# %%
#el metodo columns es para explorar las columnas de nuestro data frame
df.columns
# Out:
# Index(['rank', 'title', 'release', 'summary', 'metascore', 'userscore', 'link',
#        'img_url'],
#       dtype='object')

# %%
#para mostrar la información de una sola columna o atributo es necesario colocar el nombre del mismo
df.title
# Out:
# 0                     Rectify: Season 4
# 1      The Larry Sanders Show: Season 4
# 2                  Murder One: Season 1
# 3      The Larry Sanders Show: Season 6
# 4                Breaking Bad: Season 5
#                      ...
# 995     The Inbetweeners (UK): Season 1
# 996              Battle Creek: Season 1
# 997                London Spy: Season 1
# 998      The Bletchley Circle: Season 1
# 999             The Middleman: Season 1
# Name: title, Length: 1000, dtype: object

# %%
#para mostrar los tipos de datos de las columnas usar el metodo dtypes
df.dtypes
# Out:
# rank          int64
# title        object
# release      object
# summary      object
# metascore     int64
# userscore    object
# link         object
# img_url      object
# dtype: object

# %%
#para mostrar los valores 
df.values
# Out:
# array([[1, 'Rectify: Season 4', 'October 26, 2016', ..., '8.7',
#         'https://www.metacritic.com/tv/rectify/season-4',
#         'https://static.metacritic.com/images/products/tv/8/73cb1a676477b2f19058fac1ca57a4f4-98.jpg'],
#        [2, 'The Larry Sanders Show: Season 4', 'July 19, 1995', ...,
#         '5.8',
#         'https://www.metacritic.com/tv/the-larry-sanders-show/season-4',
#         'https://static.metacritic.com/images/products/tv/8/6e3d8b562b95c82cd4b1c43e0b2b2721-98.jpg'],
#        [3, 'Murder One: Season 1', 'September 19, 1995', ..., '6.4',
#         'https://www.metacritic.com/tv/murder-one/season-1',
#         'https://static.metacritic.com/images/products/tv/8/0dbe20d1432d4dc9d85f5d0cdd7c6439-98.jpg'],
#        ...,
#        [998, 'London Spy: Season 1', 'January 21, 2016', ..., '7.7',
#         'https://www.metacritic.com/tv/london-spy/season-1',
#         'https://static.metacritic.com/images/products/tv/1/f25b870c777d7112f68e1f9bd98fc029-98.jpg'],
# ...
