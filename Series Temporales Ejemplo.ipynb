# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import time
import pandas as pd
np.random.seed(0)
df = pd.read_csv(r"C:\Users\marcos.sandovalr\Documents\Marcos Privada\Python Big Data\Python-TensorFlow-for-Machine-Learning-Neural-Network-Text-Classification-Tutorial\base_datos_2008.csv", nrows=1000000)
df2 = df[df["Origin"].isin(["ATL","HOU","IND"])]

# %%
times = []
for i in np.arange(len(df)):
    times.append(datetime.datetime(year=2008, month = df.loc[i,"Month"], day = df.loc[i,"DayofMonth"]))

# %%
times[50000]

# %%
df["Time"] = times

# %%
data = df.groupby(by=["Time"],as_index=False)["DepDelay","ArrDelay"].mean()
data.head()
# Out:
# C:\Users\MARCOS~1.SAN\AppData\Local\Temp/ipykernel_17132/2302406288.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by=["Time"],as_index=False)["DepDelay","ArrDelay"].mean()
#         Time   DepDelay   ArrDelay
# 0 2008-01-01  19.013954  19.211324
# 1 2008-01-02  22.165289  21.230027
# 2 2008-01-03  16.112306  13.831777
# 3 2008-01-04  13.758581  11.558525
# 4 2008-01-05  17.386419  15.903450

# %%
sns.lineplot(data["Time"], data["DepDelay"])
# Out:
# C:\Users\marcos.sandovalr\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Time', ylabel='DepDelay'>

# %%
sns.lineplot(data = data)
# Out:
# <AxesSubplot:>

# %%
times = []
for i in df2.index:
    times.append(datetime.datetime(year = 2008, month = df2.loc[i,"Month"], day=df2.loc[i,"DayofMonth"]))

df2["Time"] = times
# Out:
# C:\Users\MARCOS~1.SAN\AppData\Local\Temp/ipykernel_17132/3559285301.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Time"] = times

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Time",y="ArrDelay",hue="Origin",data=df2)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='ArrDelay'>
