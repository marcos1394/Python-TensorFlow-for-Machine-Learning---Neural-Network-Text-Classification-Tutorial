# %%
#importamos la libreria de pandas
import pandas as pd
# leemos nuestro archivo csv y lo guardamos en un data frame
df = pd.read_csv(r"C:\Users\marcos.sandovalr\Documents\Marcos Privada\Python Big Data\CarrosRobados.csv", nrows=1000)

# %%
#para obtener un rango del conjunto de datos colocamos llaves y entre estas el valor inicial y final
df[0:20]
# Out:
#      Color   VehicleModel           VehicleDesc  ModelYear   VehicleType  \
# 0   Silver        Trailer              BST2021D       2021       Trailer
# 1   Silver        Trailer   OUTBACK BOATS FT470       2021  Boat Trailer
# 2   Silver        Trailer            ASD JETSKI       2021  Boat Trailer
# 3   Silver        Trailer               MSC 7X4       2021       Trailer
# 4   Silver        Trailer             D-MAX 8X5       2018       Trailer
# 5    Black         Yamaha               YZF-R6T       2005      Roadbike
# 6   Silver        Trailer      CAAR TRANSPORTER       2021       Trailer
# 7   Silver        Trailer                  BOAT       2001  Boat Trailer
# 8   Silver        Briford         7X4'6" 1000KG       2021       Trailer
# 9   Silver        Briford            8X4 TANDEM       2020       Trailer
# 10  Silver        Trailer             HOMEBUILT       2018       Trailer
# 11  Silver  Factory Built  BRENT SMITH TRAILERS       2018       Trailer
# ...

# %%
#aplicar filtros
df[df["ModelYear"] > 2010]
# Out:
#       Color   VehicleModel          VehicleDesc  ModelYear   VehicleType  \
# 0    Silver        Trailer             BST2021D       2021       Trailer
# 1    Silver        Trailer  OUTBACK BOATS FT470       2021  Boat Trailer
# 2    Silver        Trailer           ASD JETSKI       2021  Boat Trailer
# 3    Silver        Trailer              MSC 7X4       2021       Trailer
# 4    Silver        Trailer            D-MAX 8X5       2018       Trailer
# ..      ...            ...                  ...        ...           ...
# 993   Black        Aprilia                TUONO       2015      Roadbike
# 994   Black  Factory Built                MOTUS       2015         Moped
# 995   Black      TNT Motor                 ROMA       2016         Moped
# 996     Red         Yamaha                  YZF       2016      Roadbike
# 997   White            KTM                  200       2016      Roadbike
#
#      DateStolen       Location
# 0     5/11/2021      Waitemata
# ...

# %%
#df.dtypes
#filtros compuestos
df[(df['Color'] == 'Black') & (df['ModelYear'] > 2015)]
# Out:
#      Color     VehicleModel    VehicleDesc  ModelYear VehicleType  DateStolen  \
# 39   Black        Homebuilt        TRAILER       2021     Trailer  27/12/2021
# 58   Black          Trailer      HOMEBUILT       2021     Trailer   6/03/2022
# 63   Black          Trailer  IFOR WILLIAMS       2018     Trailer   6/01/2022
# 98   Black          Trailer      HOMEBUILT       2022     Trailer  14/02/2022
# 101  Black        Homebuilt        TRAILER       2022     Trailer  12/03/2022
# ..     ...              ...            ...        ...         ...         ...
# 982  Black            Honda            GLC       2018    Roadbike   4/03/2022
# 984  Black        TNT Motor           OTTO       2019       Moped  28/03/2022
# 989  Black  Harley Davidson         STREET       2019    Roadbike  17/03/2022
# 990  Black            Forza        CICLONE       2019       Moped   8/02/2022
# 995  Black        TNT Motor           ROMA       2016       Moped  23/02/2022
#
#              Location
# ...

# %%
#al colocar el nombre de la columna podemos utilizar el metodo isin en el cual podemos especificar n cantidad de valroes que esten en dicha columna
df[df.VehicleModel.isin(["Honda", "Harley Davidson"])]
# Out:
#       Color     VehicleModel VehicleDesc  ModelYear VehicleType  DateStolen  \
# 13     Blue            Honda       TODAY       2007       Moped  23/01/2022
# 62   Yellow            Honda    TODAY 50       2008       Moped  19/12/2021
# 96      Red            Honda          VT       2005    Roadbike  19/03/2022
# 97     Blue            Honda         CBR       2000    Roadbike  31/01/2022
# 111     Red  Harley Davidson      FXSTDI       2004    Roadbike  16/01/2022
# ..      ...              ...         ...        ...         ...         ...
# 968  Silver  Harley Davidson       V-ROD       2003    Roadbike  16/10/2021
# 976   White            Honda         APE       2002       Moped  17/01/2022
# 982   Black            Honda         GLC       2018    Roadbike   4/03/2022
# 989   Black  Harley Davidson      STREET       2019    Roadbike  17/03/2022
# 998   Black  Harley Davidson         FXD       2007    Roadbike  16/11/2021
#
#              Location
# 13      Auckland City
# ...

# %%
#podemos utilizar un método natural de pandas como lo es isna para que nos muestre los valores nulos
df[pd.isna(df["Color"])]
# Out:
#     Color VehicleModel VehicleDesc  ModelYear VehicleType  DateStolen  \
# 179   NaN          NaN         NaN          0         NaN  14/03/2022
# 302   NaN          NaN         NaN          0         NaN   9/10/2021
# 528   NaN          NaN         NaN          0         NaN  23/11/2021
#
#              Location
# 179  Counties/Manukau
# 302           Eastern
# 528     Auckland City
